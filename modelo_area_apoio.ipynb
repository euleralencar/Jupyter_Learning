# %% [markdown]
# # Configurar o ambiente para trabalho

# %%
#importar pacote
import os

#mudar o diretório corrente
cwd = os.getcwd()
cwd

#mudar o diretório
os.chdir("C:\\Users\\t318769\\Documents\\Jupyter Notebooks\\dim_area_apoio")

# %%
os.listdir('.')
# Out:
# ['areadeatuacao_bdtotal.xlsx']

# %% [markdown]
# # Utilizando o Pandas

# %%
# Import pandas
import pandas as pd
import numpy as np

# Assign spreadsheet filename to `file`
file = 'areadeatuacao_bdtotal.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# Print the sheet names
print(xl.sheet_names)

# Load a sheet into a DataFrame by name: df1
df1 = xl.parse('data')
# Out:
# ['data', 'fonte']

# %%
#Como verificar o objeto?

# %%
df = pd.read_excel(file)
type(df)
print(df)
# Out:
#                             circunscricao  \
# 0                    BRASÍLIA - CARTÓRIOS
# 1                    BRASÍLIA - CARTÓRIOS
# 2                    BRASÍLIA - CARTÓRIOS
# 3                    BRASÍLIA - CARTÓRIOS
# 4                    BRASÍLIA - CARTÓRIOS
# 5                    BRASÍLIA - CARTÓRIOS
# 6                    BRASÍLIA - CARTÓRIOS
# 7                    BRASÍLIA - CARTÓRIOS
# 8                    BRASÍLIA - CARTÓRIOS
# 9                    BRASÍLIA - CARTÓRIOS
# 10                   BRASÍLIA - CARTÓRIOS
# 11                   BRASÍLIA - CARTÓRIOS
# 12                   BRASÍLIA - CARTÓRIOS
# 13                   BRASÍLIA - CARTÓRIOS
# 14                   BRASÍLIA - CARTÓRIOS
# 15                   BRASÍLIA - CARTÓRIOS
# 16                   BRASÍLIA - CARTÓRIOS
# 17                   BRASÍLIA - CARTÓRIOS
# 18                   BRASÍLIA - CARTÓRIOS
# 19                   BRASÍLIA - CARTÓRIOS
# 20                   BRASÍLIA - CARTÓRIOS
# ...

# %%
df.head(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-28bdc722660f> in <module>
# ----> 1 df.head(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in head(self, n)
#    3970         """
#    3971
# -> 3972         return self.iloc[:n]
#    3973
#    3974     def tail(self, n=5):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2078
#    2079         if isinstance(key, slice):
# -> 2080             return self._get_slice_axis(key, axis=axis)
#    2081
# ...

# %%
df1 = pd.DataFrame(df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-9853be7f27db> in <module>
# ----> 1 df1 = pd.DataFrame(df, ignore_index=True)
#
# TypeError: __init__() got an unexpected keyword argument 'ignore_index'

# %% [markdown]
# Este resultado diz respeito

# %% [markdown]
# # Titulo
